# %%
import pandas as pd

# %%
stx_df = pd.read_csv('../data/sptx/stxBCscaled.csv', delimiter=',')

# %%
stx_df
# Out:
#      Unnamed: 0  AAACAAGTATCTCCCA-1  AAACACCAATAACTGC-1  AAACAGAGCGACTCCT-1  \
# 0        SAMD11           -0.237528           -0.155576           -0.202988
# 1         ISG15           -2.379990           -0.589019            0.898563
# 2          AGRN            0.527216           -1.188143           -0.648410
# 3       TNFRSF4            1.117339           -0.326612           -0.453792
# 4         MXRA8           -1.139145            0.253466            0.912209
# ...         ...                 ...                 ...                 ...
# 2995    ARHGAP4           -0.380757           -0.682868           -0.966180
# 2996       FLNA            1.564163           -0.587132           -1.259025
# 2997       GAB3           -0.677687            2.307625           -0.563717
# 2998       MPP1           -0.351306            4.622280            0.129048
# 2999       F8A1           -0.374466           -0.233402           -0.315122
#
# ...

# %%
val_df = pd.read_csv('validation.txt', delimiter='\t').transpose()

# %%
val_df.set_
# Out:
#                                                      0     \
# Image           Visium_FFPE_Human_Breast_Cancer_image.tif
# Name                                   GTAGGTGATCCGTGTA-1
# Class                                  GTAGGTGATCCGTGTA-1
# Parent                                              Image
# ROI                                              Geometry
# ...                                                   ...
# IFI6                                               3.0438
# THEMIS2                                            0.5539
# Num Detections                                          8
# Area µm^2                                          2094.7
# Perimeter µm                                       392.09
#
#                                                      1     \
# Image           Visium_FFPE_Human_Breast_Cancer_image.tif
# Name                                   CGTTGTCGGCAATTGA-1
# Class                                  CGTTGTCGGCAATTGA-1
# ...
